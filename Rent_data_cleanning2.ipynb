# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# Reading the file
df = pd.read_csv("Resources//Data//Zillowrent.csv", index_col=False)
df
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0        91940         0       77449        zip        TX    TX          NaN
# 1        91982         1       77494        zip        TX    TX          NaN
# 2        93144         2       79936        zip        TX    TX      El Paso
# 3        62093         4       11385        zip        NY    NY     New York
# 4        95992         5       90011        zip        CA    CA  Los Angeles
# ...        ...       ...         ...        ...       ...   ...          ...
# 5822     91695     22596       77046        zip        TX    TX      Houston
# 5823     84604     22874       60602        zip        IL    IL      Chicago
# 5824     60648     23294        7311        zip        NJ    NJ  Jersey City
# 5825     87202     26561       66517        zip        KS    KS        Ogden
# 5826    418163     30072       89158        zip        NV    NV    Las Vegas
#
# ...

# %%
# Droping the column Names
df = df.drop(["RegionName","SizeRank","StateName","RegionType","City","State","Metro","CountyName"], axis=1)
df
# Out:
#       RegionID   2015-03-31   2015-04-30   2015-05-31   2015-06-30  \
# 0        91940  1273.974267  1287.901057  1295.140739  1308.446006
# 1        91982  1590.037308  1592.007297  1606.068779  1613.571599
# 2        93144          NaN          NaN          NaN          NaN
# 3        62093  2182.238737  2222.635952  2249.036093  2271.809425
# 4        95992          NaN          NaN          NaN          NaN
# ...        ...          ...          ...          ...          ...
# 5822     91695          NaN          NaN          NaN          NaN
# 5823     84604          NaN          NaN          NaN          NaN
# 5824     60648          NaN          NaN          NaN          NaN
# 5825     87202          NaN          NaN          NaN          NaN
# 5826    418163          NaN          NaN          NaN          NaN
#
#        2015-07-31   2015-08-31   2015-09-30   2015-10-31   2015-11-30  ...  \
# 0     1317.051052  1326.361467  1323.489210  1321.972513  1321.184903  ...
# ...

# %%
#df = df.RegionID.astype(str)
#df

# %%
 # Rermoving the index column  
df.set_index("RegionID", inplace = True)

# %%
# Removing the Region Id column name
df = df.rename_axis(None, axis=0)
df
# Out:
#          2015-03-31   2015-04-30   2015-05-31   2015-06-30   2015-07-31  \
# 91940   1273.974267  1287.901057  1295.140739  1308.446006  1317.051052
# 91982   1590.037308  1592.007297  1606.068779  1613.571599  1620.530820
# 93144           NaN          NaN          NaN          NaN          NaN
# 62093   2182.238737  2222.635952  2249.036093  2271.809425  2281.285678
# 95992           NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 91695           NaN          NaN          NaN          NaN          NaN
# 84604           NaN          NaN          NaN          NaN          NaN
# 60648           NaN          NaN          NaN          NaN          NaN
# 87202           NaN          NaN          NaN          NaN          NaN
# 418163          NaN          NaN          NaN          NaN          NaN
#
#          2015-08-31   2015-09-30   2015-10-31   2015-11-30   2015-12-31  ...  \
# ...

# %%
# Droping the null values
# df.dropna()

# %%
# changing the date column to rows 
df2 = df.transpose()
df2
# Out:
#                  91940        91982        93144        62093        95992   \
# 2015-03-31  1273.974267  1590.037308          NaN  2182.238737          NaN
# 2015-04-30  1287.901057  1592.007297          NaN  2222.635952          NaN
# 2015-05-31  1295.140739  1606.068779          NaN  2249.036093          NaN
# 2015-06-30  1308.446006  1613.571599          NaN  2271.809425          NaN
# 2015-07-31  1317.051052  1620.530820          NaN  2281.285678          NaN
# ...                 ...          ...          ...          ...          ...
# 2022-07-31  1812.363772  1988.993075  1307.684622  3025.357640  1813.063427
# 2022-08-31  1855.115706  1998.600542  1340.554919  3098.262604  1877.776739
# 2022-09-30  1851.684326  2004.016488  1352.197199  3103.604142  1901.072562
# 2022-10-31  1829.774440  1982.343205  1329.549930  3102.877087  1953.029775
# 2022-11-30  1795.417600  1962.917026  1341.994048  3073.108549  1950.666667
#
# ...

# %%
# Setting the index column name as Date 
df2.index.rename("Date", inplace=True)
#df2.dropna()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 2015-03-31 to 2022-11-30
# Columns: 5827 entries, 91940 to 418163
# dtypes: float64(5827)
# memory usage: 4.1+ MB

# %%
# Copy the column names as zipcode
df3 = df2[[91940,91982,62093,91733, 62010] ].copy()
df4 = df3.dropna().round()
df4
# Out:
#              91940   91982   62093   91733   62010
# Date
# 2015-03-31  1274.0  1590.0  2182.0  1192.0  2824.0
# 2015-04-30  1288.0  1592.0  2223.0  1205.0  2881.0
# 2015-05-31  1295.0  1606.0  2249.0  1207.0  2935.0
# 2015-06-30  1308.0  1614.0  2272.0  1214.0  2951.0
# 2015-07-31  1317.0  1621.0  2281.0  1216.0  2964.0
# ...            ...     ...     ...     ...     ...
# 2022-07-31  1812.0  1989.0  3025.0  1685.0  4056.0
# 2022-08-31  1855.0  1999.0  3098.0  1667.0  4082.0
# 2022-09-30  1852.0  2004.0  3104.0  1651.0  4109.0
# 2022-10-31  1830.0  1982.0  3103.0  1636.0  4078.0
# 2022-11-30  1795.0  1963.0  3073.0  1652.0  4055.0
#
# [93 rows x 5 columns]

# %%
df4.rename(columns = {"Date": "Date",91940:'91940', 91982:"91982",62093:"62093",91733:"91733",62010:"62010"}, inplace = True)
df4
# Out:
#              91940   91982   62093   91733   62010
# Date
# 2015-03-31  1274.0  1590.0  2182.0  1192.0  2824.0
# 2015-04-30  1288.0  1592.0  2223.0  1205.0  2881.0
# 2015-05-31  1295.0  1606.0  2249.0  1207.0  2935.0
# 2015-06-30  1308.0  1614.0  2272.0  1214.0  2951.0
# 2015-07-31  1317.0  1621.0  2281.0  1216.0  2964.0
# ...            ...     ...     ...     ...     ...
# 2022-07-31  1812.0  1989.0  3025.0  1685.0  4056.0
# 2022-08-31  1855.0  1999.0  3098.0  1667.0  4082.0
# 2022-09-30  1852.0  2004.0  3104.0  1651.0  4109.0
# 2022-10-31  1830.0  1982.0  3103.0  1636.0  4078.0
# 2022-11-30  1795.0  1963.0  3073.0  1652.0  4055.0
#
# [93 rows x 5 columns]

# %%
# Storing the data to csv 
file = df4.to_csv("Resources//Data//homerent_cleaneddata_zip.csv")
