# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data = Path('./Resources/data/Zip_zori_sm_month_org.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0     91940         0       77449        zip        TX    TX          NaN
# 1     91982         1       77494        zip        TX    TX          NaN
# 2     93144         2       79936        zip        TX    TX      El Paso
# 3     62093         4       11385        zip        NY    NY     New York
# 4     95992         5       90011        zip        CA    CA  Los Angeles
#
#                                    Metro          CountyName   2015-03-31  \
# 0   Houston-The Woodlands-Sugar Land, TX       Harris County  1273.974267
# 1   Houston-The Woodlands-Sugar Land, TX    Fort Bend County  1590.037308
# 2                            El Paso, TX      El Paso County          NaN
# 3  New York-Newark-Jersey City, NY-NJ-PA       Queens County  2182.238737
# 4     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County          NaN
#
#    ...   2022-02-28   2022-03-31   2022-04-30   2022-05-31   2022-06-30  \
# ...

# %%
df.shape
# Out:
# (5827, 102)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5827 entries, 0 to 5826
# Columns: 102 entries, RegionID to 2022-11-30
# dtypes: float64(93), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#             RegionID      SizeRank    RegionName   2015-03-31   2015-04-30  \
# count    5827.000000   5827.000000   5827.000000  1097.000000  1117.000000
# mean    85404.299468   4058.713746  54244.315085  1416.238371  1430.415230
# std     41773.208639   3207.038897  30109.614146   616.770115   618.052795
# min     58196.000000      0.000000   1001.000000    84.636368   468.530514
# 25%     70847.500000   1608.500000  30049.500000  1028.029625  1043.421486
# 50%     81285.000000   3392.000000  52405.000000  1253.764697  1265.095706
# 75%     94320.500000   5748.500000  81504.500000  1636.456130  1664.394397
# max    787972.000000  30072.000000  99705.000000  5949.940003  6090.203331
#
#         2015-05-31   2015-06-30    2015-07-31    2015-08-31    2015-09-30  \
# count  1134.000000  1140.000000   1153.000000   1157.000000   1170.000000
# mean   1441.849204  1453.213109   1497.373191   1504.747132   1508.016823
# ...

# %%
df1 = df.copy(deep=True)
df1=df1.melt(id_vars=['RegionID','SizeRank','RegionName','RegionType','StateName','State','City','Metro','CountyName'], var_name='Date', value_name='Rent')
df1
# Out:
#         RegionID  SizeRank  RegionName RegionType StateName State  \
# 0          91940         0       77449        zip        TX    TX
# 1          91982         1       77494        zip        TX    TX
# 2          93144         2       79936        zip        TX    TX
# 3          62093         4       11385        zip        NY    NY
# 4          95992         5       90011        zip        CA    CA
# ...          ...       ...         ...        ...       ...   ...
# 541906     91695     22596       77046        zip        TX    TX
# 541907     84604     22874       60602        zip        IL    IL
# 541908     60648     23294        7311        zip        NJ    NJ
# 541909     87202     26561       66517        zip        KS    KS
# 541910    418163     30072       89158        zip        NV    NV
#
#                City                                  Metro  \
# 0               NaN   Houston-The Woodlands-Sugar Land, TX
# ...

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#             RegionID      SizeRank    RegionName   2015-03-31   2015-04-30  \
# count     908.000000    908.000000    908.000000   908.000000   908.000000
# mean    87017.435022   2172.549559  52335.020925  1449.841775  1461.870739
# std     48055.121686   2169.429997  31009.355254   620.597170   627.578164
# min     58625.000000      4.000000   2111.000000   448.487272   468.530514
# 25%     69999.750000    589.500000  28402.500000  1042.853031  1051.255404
# 50%     74617.000000   1529.000000  37041.000000  1276.822194  1289.138094
# 75%     94842.250000   3163.250000  85205.250000  1708.302748  1715.555561
# max    422746.000000  22136.000000  98661.000000  5949.940003  6090.203331
#
#         2015-05-31   2015-06-30   2015-07-31   2015-08-31   2015-09-30  ...  \
# count   908.000000   908.000000   908.000000   908.000000   908.000000  ...
# mean   1472.979846  1484.285942  1492.867214  1500.399615  1504.408175  ...
# ...

# %%
df1 = df1.dropna()

# %%
df1.describe()
# Out:
#             RegionID       SizeRank     RegionName           Rent
# count  226062.000000  226062.000000  226062.000000  226062.000000
# mean    86955.002172    3072.268245   56486.321239    1761.723133
# std     44998.143578    2757.823798   30657.022798    1136.645198
# min     58196.000000       2.000000    1001.000000      32.010176
# 25%     70909.000000    1018.000000   30122.000000    1257.220826
# 50%     84621.000000    2331.000000   60610.000000    1574.427441
# 75%     95304.000000    4404.000000   85340.000000    2055.377418
# max    787972.000000   30072.000000   99705.000000   67500.000000

# %%
df1.head()
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 3      62093         4       11385        zip        NY    NY      New York
# 6      91733         7       77084        zip        TX    TX       Houston
# 11     61807        15       10467        zip        NY    NY      New York
# 12     62037        16       11226        zip        NY    NY      New York
# 13     92593        17       78660        zip        TX    TX  Pflugerville
#
#                                     Metro     CountyName        Date  \
# 3   New York-Newark-Jersey City, NY-NJ-PA  Queens County  2015-03-31
# 6    Houston-The Woodlands-Sugar Land, TX  Harris County  2015-03-31
# 11  New York-Newark-Jersey City, NY-NJ-PA   Bronx County  2015-03-31
# 12  New York-Newark-Jersey City, NY-NJ-PA   Kings County  2015-03-31
# 13       Austin-Round Rock-Georgetown, TX  Travis County  2015-03-31
#
#            Rent
# 3   2182.238737
# 6   1192.210628
# 11  1310.498298
# 12  1932.094731
# ...

# %%
df1.shape # high level understanding
# Out:
# (226062, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226062 entries, 3 to 541910
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   RegionID    226062 non-null  int64
#  1   SizeRank    226062 non-null  int64
#  2   RegionName  226062 non-null  int64
#  3   RegionType  226062 non-null  object
#  4   StateName   226062 non-null  object
#  5   State       226062 non-null  object
#  6   City        226062 non-null  object
#  7   Metro       226062 non-null  object
#  8   CountyName  226062 non-null  object
#  9   Date        226062 non-null  object
#  10  Rent        226062 non-null  float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 20.7+ MB

# %%
# first_df = df1[df.RegionID == 11385]
# df1.query('RegionID = 11385')
df1[df1.RegionID == 62093].count()
# Out:
# RegionID      93
# SizeRank      93
# RegionName    93
# RegionType    93
# StateName     93
# State         93
# City          93
# Metro         93
# CountyName    93
# Date          93
# Rent          93
# dtype: int64

# %%
df1['Date'] =  pd.to_datetime(df1['Date'])

# %%
df1["Year"] = pd.DatetimeIndex(df1['Date']).year
df1.head()
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 3      62093         4       11385        zip        NY    NY      New York
# 6      91733         7       77084        zip        TX    TX       Houston
# 11     61807        15       10467        zip        NY    NY      New York
# 12     62037        16       11226        zip        NY    NY      New York
# 13     92593        17       78660        zip        TX    TX  Pflugerville
#
#                                     Metro     CountyName       Date  \
# 3   New York-Newark-Jersey City, NY-NJ-PA  Queens County 2015-03-31
# 6    Houston-The Woodlands-Sugar Land, TX  Harris County 2015-03-31
# 11  New York-Newark-Jersey City, NY-NJ-PA   Bronx County 2015-03-31
# 12  New York-Newark-Jersey City, NY-NJ-PA   Kings County 2015-03-31
# 13       Austin-Round Rock-Georgetown, TX  Travis County 2015-03-31
#
#            Rent  Year
# 3   2182.238737  2015
# 6   1192.210628  2015
# 11  1310.498298  2015
# ...
