# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('Zip_zori_sm_sa_month.csv'))
df.head(5)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0     91940         0       77449        zip        TX    TX          NaN
# 1     91982         1       77494        zip        TX    TX          NaN
# 2     93144         2       79936        zip        TX    TX      El Paso
# 3     62093         4       11385        zip        NY    NY     New York
# 4     95992         5       90011        zip        CA    CA  Los Angeles
#
#                                    Metro          CountyName   2015-03-31  \
# 0   Houston-The Woodlands-Sugar Land, TX       Harris County  1274.486599
# 1   Houston-The Woodlands-Sugar Land, TX    Fort Bend County  1583.440822
# 2                            El Paso, TX      El Paso County          NaN
# 3  New York-Newark-Jersey City, NY-NJ-PA       Queens County  2200.677014
# 4     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County          NaN
#
#    ...   2022-02-28   2022-03-31   2022-04-30   2022-05-31   2022-06-30  \
# ...

# %%
df.columns.to_list()
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'State',
#  'City',
#  'Metro',
#  'CountyName',
#  '2015-03-31',
#  '2015-04-30',
#  '2015-05-31',
#  '2015-06-30',
#  '2015-07-31',
#  '2015-08-31',
#  '2015-09-30',
#  '2015-10-31',
#  '2015-11-30',
#  '2015-12-31',
#  '2016-01-31',
#  '2016-02-29',
#  '2016-03-31',
#  '2016-04-30',
#  '2016-05-31',
#  '2016-06-30',
#  '2016-07-31',
#  '2016-08-31',
#  '2016-09-30',
#  '2016-10-31',
#  '2016-11-30',
#  '2016-12-31',
#  '2017-01-31',
#  '2017-02-28',
#  '2017-03-31',
#  '2017-04-30',
#  '2017-05-31',
#  '2017-06-30',
#  '2017-07-31',
#  '2017-08-31',
#  '2017-09-30',
#  '2017-10-31',
#  '2017-11-30',
#  '2017-12-31',
#  '2018-01-31',
#  '2018-02-28',
#  '2018-03-31',
#  '2018-04-30',
#  '2018-05-31',
#  '2018-06-30',
#  '2018-07-31',
#  '2018-08-31',
#  '2018-09-30',
#  '2018-10-31',
#  '2018-11-30',
#  '2018-12-31',
#  '2019-01-31',
#  '2019-02-28',
#  '2019-03-31',
#  '2019-04-30',
#  '2019-05-31',
# ...

# %%
df.count()
# Out:
# RegionID      5825
# SizeRank      5825
# RegionName    5825
# RegionType    5825
# StateName     5825
#               ...
# 2022-07-31    4678
# 2022-08-31    4800
# 2022-09-30    4926
# 2022-10-31    5248
# 2022-11-30    5816
# Length: 102, dtype: int64

# %%
df = df.dropna()

# %%
df.count()
# Out:
# RegionID      907
# SizeRank      907
# RegionName    907
# RegionType    907
# StateName     907
#              ...
# 2022-07-31    907
# 2022-08-31    907
# 2022-09-30    907
# 2022-10-31    907
# 2022-11-30    907
# Length: 102, dtype: int64

# %%
df.head(5)
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 3      62093         4       11385        zip        NY    NY   New York
# 6      91733         7       77084        zip        TX    TX    Houston
# 11     61807        15       10467        zip        NY    NY   New York
# 12     62037        16       11226        zip        NY    NY   New York
# 15     96107        19       90250        zip        CA    CA  Hawthorne
#
#                                     Metro          CountyName   2015-03-31  \
# 3   New York-Newark-Jersey City, NY-NJ-PA       Queens County  2200.677014
# 6    Houston-The Woodlands-Sugar Land, TX       Harris County  1216.294249
# 11  New York-Newark-Jersey City, NY-NJ-PA        Bronx County  1309.224678
# 12  New York-Newark-Jersey City, NY-NJ-PA        Kings County  1863.451061
# 15     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  1077.953273
#
#     ...   2022-02-28   2022-03-31   2022-04-30   2022-05-31   2022-06-30  \
# ...

# %%
df = df.rename(columns = {'RegionName':'Zip Code'})

# %%
df.head(5)
# Out:
#     RegionID  SizeRank  Zip Code RegionType StateName State       City  \
# 3      62093         4     11385        zip        NY    NY   New York
# 6      91733         7     77084        zip        TX    TX    Houston
# 11     61807        15     10467        zip        NY    NY   New York
# 12     62037        16     11226        zip        NY    NY   New York
# 15     96107        19     90250        zip        CA    CA  Hawthorne
#
#                                     Metro          CountyName   2015-03-31  \
# 3   New York-Newark-Jersey City, NY-NJ-PA       Queens County  2200.677014
# 6    Houston-The Woodlands-Sugar Land, TX       Harris County  1216.294249
# 11  New York-Newark-Jersey City, NY-NJ-PA        Bronx County  1309.224678
# 12  New York-Newark-Jersey City, NY-NJ-PA        Kings County  1863.451061
# 15     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  1077.953273
#
#     ...   2022-02-28   2022-03-31   2022-04-30   2022-05-31   2022-06-30  \
# ...

# %%
df.drop(columns = ['RegionID','SizeRank','RegionType','StateName'])
# Out:
#       Zip Code State          City  \
# 3        11385    NY      New York
# 6        77084    TX       Houston
# 11       10467    NY      New York
# 12       11226    NY      New York
# 15       90250    CA     Hawthorne
# ...        ...   ...           ...
# 5616      2111    MA        Boston
# 5684      2113    MA        Boston
# 5712     19127    PA  Philadelphia
# 5794     10006    NY      New York
# 5819     11109    NY      New York
#
#                                             Metro           CountyName  \
# 3           New York-Newark-Jersey City, NY-NJ-PA        Queens County
# 6            Houston-The Woodlands-Sugar Land, TX        Harris County
# 11          New York-Newark-Jersey City, NY-NJ-PA         Bronx County
# 12          New York-Newark-Jersey City, NY-NJ-PA         Kings County
# 15             Los Angeles-Long Beach-Anaheim, CA   Los Angeles County
# ...                                           ...                  ...
# ...

# %%
df.pivot(columns='var', values='val')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var'
#
# The above exception was the direct cause of the following exception:
#
# ...
